# %%
import os
os.environ['GEMINI_API_KEY'] = "Enter your Key"

# %%
import google.generativeai as genai
genai.configure(api_key=os.environ['GEMINI_API_KEY'])

# %%
model = genai.GenerativeModel('gemini-2.5-flash-preview-04-17')

# %%
response = model.generate_content("What would be future scope of Generative AI in 2030?")
print(response.text)
# Out:
# Okay, let's project the scope of Generative AI forward to 2030. Based on current trajectories, rapid development, and increasing integration, here's what the landscape is likely to look like:
#
# **Key Areas of Advancement & Capabilities by 2030:**
#
# 1.  **Hyper-Personalization and Contextual Understanding:**
#     *   Gen AI models will not just generate content but understand and adapt *deeply* to individual user context, preferences, history, and even emotional state (inferred).
#     *   They will maintain long-term memory and continuity across interactions and tasks.
#     *   Generation will be highly tailored – from educational content that adapts to a student's learning style, to marketing copy that resonates with a specific micro-segment, to entertainment experiences that evolve with user feedback.
#
# 2.  **Seamless Multimodality and Sensory Integration:**
#     *   Current multimodal models (text + image) are just the beginning. By 2030, Gen AI will effortlessly combine and generate across text, images, video, audio, 3D models, haptic feedback instructions, and potentially even simulated sensory data.
#     *   Users will interact with AI using any combination of inputs (voice commands, sketches, reference images, text descriptions), and the AI will generate coherent outputs across different media.
#
# 3.  **Increased Reliability, Accuracy, and Reduced Hallucinations:**
#     *   Significant progress will be made in grounding Gen AI models in verifiable data and reducing factual errors or "hallucinations."
#     *   Techniques for explainability and trust will improve, making it easier to understand *why* a model generated a particular output.
#     *   Models will become more adept at handling sensitive, factual, and domain-specific information accurately.
#
# 4.  **Autonomous Agents and Complex Task Execution:**
#     *   Gen AI will move beyond single-turn prompts to orchestrate complex workflows. AI agents will be able to break down large goals into smaller tasks, interact with multiple tools and systems (like browsing the web, using software APIs, sending emails), learn from feedback, and iterate towards a solution with minimal human intervention.
#     *   This could range from planning and booking an entire complex trip to conducting preliminary research and drafting a full report on a niche topic.
#
# 5.  **Highly Efficient and Specialized Models:**
#     *   While massive general models will still exist, there will be a proliferation of smaller, highly efficient, and specialized models trained on specific datasets or optimized for particular tasks (e.g., generating code for a specific framework, creating medical images, designing specific product components).
#     *   These models will be cheaper and faster to run, making Gen AI more accessible and deployable on edge devices.
#
# 6.  **Advanced Simulation and World Modeling:**
#     *   Gen AI will be capable of building and simulating complex environments, systems, and scenarios with greater fidelity.
#     *   This has applications in scientific research (simulating biological processes, materials science), urban planning, game development (dynamic worlds and NPCs), climate modeling, and training other AI systems.
#
# **Transformative Applications and Industry Impact:**
#
# 1.  **Creative Industries:**
#     *   AI will be a ubiquitous co-creator, enabling individuals and studios to produce content (films, music, games, art, literature) at unprecedented speed and scale.
#     *   Personalized entertainment feeds generated on the fly based on mood and preference.
#     *   Democratization of high-quality content creation tools.
#
# 2.  **Software Development:**
#     *   Gen AI will generate, debug, test, and even refactor code semi-autonomously.
#     *   Developers will become more like architects and reviewers, overseeing AI agents that handle routine coding tasks.
#     *   Accelerated development cycles and lower barriers to building complex software.
#
# 3.  **Healthcare & Life Sciences:**
#     *   Generating novel drug candidates, proteins, and materials.
#     *   Simulating biological systems and clinical trials.
#     *   Generating synthetic patient data for training models while preserving privacy.
#     *   Aiding in diagnostics by generating potential findings or explanations from medical images/data.
#
# 4.  **Education:**
#     *   Highly personalized learning platforms that generate custom curricula, explanations, quizzes, and feedback tailored to each student's pace and understanding.
#     *   AI tutors capable of engaging in natural language dialogue across complex subjects.
#     *   Automated content generation for educators (lesson plans, presentations).
#
# 5.  **Manufacturing & Design:**
#     *   Generative design tools will automatically propose optimal shapes and structures based on functional requirements (e.g., lightweight, strong, cost-effective).
#     *   Simulating manufacturing processes and robotic movements.
#     *   Generating detailed blueprints and instructions.
#
# 6.  **Customer Service & Sales:**
#     *   Highly sophisticated, empathetic, and context-aware AI assistants handling a much wider range of customer interactions, resolving complex issues without human handoff.
#     *   Generating personalized sales pitches and marketing materials in real-time.
#
# 7.  **Research & Development:**
#     *   Accelerating hypothesis generation and literature review.
#     *   Generating experimental designs and analyzing results.
#     *   Discovering new patterns and insights in vast datasets.
#
# **Broader Societal and Economic Impact:**
#
# *   **Job Market Shift:** Significant disruption in tasks involving routine content creation, data entry, basic coding, and some analytical roles. Simultaneously, demand for roles involving AI oversight, prompt engineering, AI ethics, and complex problem-solving using AI tools will surge.
# *   **Increased Productivity:** Widespread integration of Gen AI will lead to significant productivity gains across many sectors.
# *   **Accessibility:** Advanced tools previously requiring specialized skills will become accessible to a wider population through natural language interfaces.
# *   **Ethical and Regulatory Landscape:** By 2030, expect more robust regulations around AI safety, bias, copyright, deepfakes, transparency, and data privacy. Ethical considerations will be paramount in development and deployment.
# *   **Information Environment:** The ability to generate highly realistic and personalized content at scale raises significant challenges regarding misinformation, propaganda, and discerning truth from synthetic reality. Tools for detecting AI-generated content will also advance.
# *   **Digital Divide:** Access to powerful Gen AI tools and the skills to use them effectively could exacerbate existing inequalities if not addressed proactively.
#
# **Challenges Remaining by 2030:**
#
# *   **Control and Alignment:** Ensuring AI actions and generations consistently align with human values and intentions remains a complex challenge.
# *   **Bias:** Mitigating biases present in training data that can perpetuate and amplify societal inequalities.
# *   **Energy Consumption:** Training and running increasingly large and complex models requires significant energy, posing environmental concerns.
# *   **Security:** Protecting models from adversarial attacks and preventing their misuse for malicious purposes (e.g., sophisticated cyberattacks, mass disinformation campaigns).
# *   **Copyright and Ownership:** Establishing clear legal frameworks for content generated by AI.
# *   **Interpretability:** While improving, fully understanding the internal workings of complex neural networks will still be an area of research.
#
# **In Summary:**
#
# By 2030, Generative AI is poised to be far more sophisticated, integrated, and autonomous than it is today. It will be a pervasive force, acting as a powerful co-pilot, collaborator, and even agent across almost all aspects of work, creativity, and potentially daily life. Its scope will expand from generating simple text or images to orchestrating complex tasks, understanding nuanced contexts, and interacting across modalities seamlessly. However, navigating the significant ethical, societal, and economic challenges associated with this power will be equally critical to realizing its full positive potential.

# %%
pip install IPython
# Out:
# Requirement already satisfied: IPython in c:\users\mahesh babu\anaconda3\lib\site-packages (8.27.0)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: decorator in c:\users\mahesh babu\anaconda3\lib\site-packages (from IPython) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\mahesh babu\anaconda3\lib\site-packages (from IPython) (0.19.1)
# Requirement already satisfied: matplotlib-inline in c:\users\mahesh babu\anaconda3\lib\site-packages (from IPython) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\mahesh babu\anaconda3\lib\site-packages (from IPython) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\mahesh babu\anaconda3\lib\site-packages (from IPython) (2.15.1)
# Requirement already satisfied: stack-data in c:\users\mahesh babu\anaconda3\lib\site-packages (from IPython) (0.2.0)
# Requirement already satisfied: traitlets>=5.13.0 in c:\users\mahesh babu\anaconda3\lib\site-packages (from IPython) (5.14.3)
# Requirement already satisfied: colorama in c:\users\mahesh babu\anaconda3\lib\site-packages (from IPython) (0.4.6)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\mahesh babu\anaconda3\lib\site-packages (from jedi>=0.16->IPython) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\mahesh babu\anaconda3\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->IPython) (0.2.5)
# Requirement already satisfied: executing in c:\users\mahesh babu\anaconda3\lib\site-packages (from stack-data->IPython) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\mahesh babu\anaconda3\lib\site-packages (from stack-data->IPython) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\mahesh babu\anaconda3\lib\site-packages (from stack-data->IPython) (0.2.2)
# Requirement already satisfied: six in c:\users\mahesh babu\anaconda3\lib\site-packages (from asttokens->stack-data->IPython) (1.16.0)

# %%
import pathlib
import textwrap

import google.generativeai as genai

from IPython.display import display
from IPython.display import Markdown

def to_markdown(text):
    text = text.replace('', '')
    return Markdown(textwrap.indent(text, '> ', predicate=lambda _: True))

# %%
for m in genai.list_models():
    if 'generateContent' in m.supported_generation_methods:
        print(m.name)
# Out:
# models/gemini-1.0-pro-vision-latest
# models/gemini-pro-vision
# models/gemini-1.5-pro-latest
# models/gemini-1.5-pro-001
# models/gemini-1.5-pro-002
# models/gemini-1.5-pro
# models/gemini-1.5-flash-latest
# models/gemini-1.5-flash-001
# models/gemini-1.5-flash-001-tuning
# models/gemini-1.5-flash
# models/gemini-1.5-flash-002
# models/gemini-1.5-flash-8b
# models/gemini-1.5-flash-8b-001
# models/gemini-1.5-flash-8b-latest
# models/gemini-1.5-flash-8b-exp-0827
# models/gemini-1.5-flash-8b-exp-0924
# models/gemini-2.5-pro-exp-03-25
# models/gemini-2.5-pro-preview-03-25
# models/gemini-2.5-flash-preview-04-17
# models/gemini-2.0-flash-exp
# models/gemini-2.0-flash
# models/gemini-2.0-flash-001
# models/gemini-2.0-flash-exp-image-generation
# models/gemini-2.0-flash-lite-001
# models/gemini-2.0-flash-lite
# models/gemini-2.0-flash-lite-preview-02-05
# models/gemini-2.0-flash-lite-preview
# models/gemini-2.0-pro-exp
# models/gemini-2.0-pro-exp-02-05
# models/gemini-exp-1206
# models/gemini-2.0-flash-thinking-exp-01-21
# models/gemini-2.0-flash-thinking-exp
# models/gemini-2.0-flash-thinking-exp-1219
# models/learnlm-1.5-pro-experimental
# models/learnlm-2.0-flash-experimental
# models/gemma-3-1b-it
# models/gemma-3-4b-it
# models/gemma-3-12b-it
# models/gemma-3-27b-it

# %%
model = genai.GenerativeModel("gemini-2.5-pro-exp-03-25")

# %%
# %%time
response = model.generate_content("create a table for summarize to a kid about datascince vs machine learning vs nlp vs deep learning vs neural network vs generative AI vs agentic ai vs mcp vs agi and save this generated file to my computer as a pdf file")
# Out:
# CPU times: total: 15.6 ms
# Wall time: 18.2 s

# %%
to_markdown(response.text)
# Out:
# > Okay, imagine we're talking about different kinds of smart computer helpers and tools! Here's a simple table to explain them to you.
# >
# > Think of them like different roles or skills people have.
# >
# > **Important Note about Saving as PDF:** I can *create* the information for the table, but I can't directly save a file to your computer as a PDF. That's a security thing! But you can easily **copy and paste** this table into a document program (like Word, Google Docs, or even a simple text editor) and then choose "Save As" or "Export" and pick "PDF".
# >
# > Here's the table:
# >
# > | What is it called?           | What it is (Simple!)                                  | What it's like... (Analogy!)                                   | What it's used for (Examples!)                                    |
# > | :--------------------------- | :---------------------------------------------------- | :------------------------------------------------------------- | :---------------------------------------------------------------- |
# > | **Data Science**             | Finding interesting patterns and answers in lots of information. | A detective finding clues to understand things.                  | Helping companies understand why people buy things, predicting trends. |
# > | **Machine Learning (ML)**    | Teaching computers to learn from data without being told exactly what to do every time. | A computer learning games or skills from practice, like you do! | Recommending videos you might like, filtering spam emails, recognizing objects in photos. |
# > | **NLP (Natural Language Processing)** | Helping computers understand, read, and use human languages (like English or Spanish). | A computer that can listen and talk to you, or read what you write. | Voice assistants (Siri, Alexa), translation apps, chatbots that answer questions. |
# > | **Deep Learning**            | A *type* of Machine Learning that uses many layers to learn really complex things. | Learning like building with many layers of blocks to make something complicated. | Recognizing faces, understanding speech better, driving self-driving cars. |
# > | **Neural Network**           | The *structure* or way Deep Learning (and some ML) is built, inspired a bit by how brains work. | A network of connected light bulbs that light up in patterns based on information. | It's the *engine* that makes Deep Learning and complex ML tasks work. |
# > | **Generative AI**            | AI that can *create* brand new things, like pictures, stories, music, or even code. | A computer that's an artist, a writer, or a musician!        | Making new art, writing creative stories, generating music, creating realistic images. |
# > | **Agentic AI**               | AI that can *act* or *do* things for you to achieve a goal, often by breaking it down into steps. | A super helpful assistant who knows how to do tasks for you (like book a table or find information online). | Managing your schedule, doing research for you, automating tasks. |
# > | **MCP (Master Control Program)** | Usually a very powerful, sometimes bossy or controlling computer program, often from science fiction stories! | The 'Big Boss Computer' from movies like Tron! (Mostly in stories!) | (In stories) Trying to run everything or control the world. |
# > | **AGI (Artificial General Intelligence)** | An AI that can do *anything* a human brain can do – learn anything, solve any problem, understand everything. (It doesn't exist yet!) | A computer with a human-like super-brain! (Not real yet!)    | (Future!) Could potentially do any job or solve any problem a human can. |
# >
# > I hope this helps make sense of these different terms! They are all related to making computers smarter and more helpful in different ways. Remember to copy and paste this into another program to save it as a PDF!

# %%
import PIL.Image

img = PIL.Image .open(r'D:\Me\MB.jpg')
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2045x1204>

# %%
model = genai.GenerativeModel('gemini-2.5-pro-exp-03-25')

# %%
response = model.generate_content(img)

to_markdown(response.text)
# Out:
# > Okay, I can see the image. It's a close-up shot of a man with dark hair, brown eyes, and a beard. He's wearing a red, white, and blue/black plaid shirt. He's looking directly at the camera and pointing his index finger towards his right eyebrow/temple area. The background is blurred (bokeh effect) and appears to be an outdoor setting, possibly with trees and other indistinct figures. There are watermarks on the image that say "TeluguClix.com".
